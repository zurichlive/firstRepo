# %%
import requests
from bs4 import BeautifulSoup
import os

# %%
## This program checks for new Veranstaltungen on admin.ch
## It offers the same functionality as the local program 
## But instead of a user input it starts with the latest already 
## scraped Veranstaltung and checks if newer ones are available

# %%
# Saving off the html code into a folder
#
#
def get_detail_new(event_id):
    # get html site for id
    r = requests.get('https://www.admin.ch/gov/de/start/dokumentation/veranstaltungen.event-id-'+str(event_id)+'.html')
    soup = BeautifulSoup(r.text, 'html.parser')
    r = BeautifulSoup(r.text, 'html.parser')
    r = r.prettify("utf-8")
    
    # get title to check if there is a result
    result_title = soup.find_all('h1')
    try:
        # if there is not a result we return empty
        if result_title[0].text.strip() == 'Veranstaltung nicht gefunden':
            print('No Veranstaltung with id '+str(event_id))
            return False
    except IndexError as e:
        print(e)
        print(result_title)

    
    # otherwise we save the html file locally
    with open("html/"+str(event_id)+".html", "wb") as file:
        print('Success! '+str(event_id))
        file.write(r)
        file.close()
        return True

# %%
# Extract the number (id) from the file name list element. Returns 0 if no number found.
#
#
def extract_number(element):
    if ".csv" in element:
        return int(element.split('.')[0])
    else:
        return 0

# %%
# read latest id that we already have stored as csv and start from there
#

lst = os.listdir('csvs')
number_of_runs = 100

if len(lst)<1:
    exit()

start_id = int(max(lst,key=extract_number).split('.')[0])+1
end_id = start_id+number_of_runs
success = False

# check for new Veranstaltungen
for x in range(start_id,end_id):
    success = False
    if get_detail_new(x):
        success = True

# if there are more we go again for the loop
if success:
    start_id = end_id
    end_id = start_id + number_of_runs
    
    # check for new Veranstaltungen
    for x in range(start_id,end_id):
        get_detail_new(x)
# Out:
# No Veranstaltung with id 7210
# No Veranstaltung with id 7211
# No Veranstaltung with id 7212
# No Veranstaltung with id 7213
# No Veranstaltung with id 7214
# No Veranstaltung with id 7215
# No Veranstaltung with id 7216
# No Veranstaltung with id 7217
# No Veranstaltung with id 7218
# No Veranstaltung with id 7219
# No Veranstaltung with id 7220
# No Veranstaltung with id 7221
# No Veranstaltung with id 7222
# No Veranstaltung with id 7223
# No Veranstaltung with id 7224
# No Veranstaltung with id 7225
# No Veranstaltung with id 7226
# No Veranstaltung with id 7227
# No Veranstaltung with id 7228
# No Veranstaltung with id 7229
# No Veranstaltung with id 7230
# No Veranstaltung with id 7231
# No Veranstaltung with id 7232
# No Veranstaltung with id 7233
