# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
path_screenshots = '/screenshots/'

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver') #because we installed with homebrew

# %%
#driver.get('https://www.vtg.admin.ch/de/die-schweizer-armee/hoehere-stabsoffiziere/hso.html')
driver.get("http://www.python.org")

# %%
#driver.save_screenshot(path_screenshots+'0001'+'.png')
# Out:
# False

# %%
element_search = driver.find_element_by_name('q') #type or class also possible

# %%
element_search.send_keys('pycon')

# %%
element_search.clear()

# %%
element_search.send_keys('pycon')

# %%
element_search.send_keys(Keys.RETURN)

# %%
# Alternative: find search button name and use it
button = driver.find_element_by_name('submit')

# %%
button.click()

# %%
# now we have the page --> BeatifulSoup or 
# --> save to file and then BeautifulSoup
driver.page_source
# Out:
# '<!DOCTYPE html><!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]--><!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]--><!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]--><!--[if gt IE 8]><!--><html xmlns="http://www.w3.org/1999/xhtml" class="js no-touch geolocation fontface generatedcontent svg formvalidation placeholder boxsizing retina" lang="en" dir="ltr" style=""><!--<![endif]--><head>\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js" />\n\n    <meta name="application-name" content="Python.org" />\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language" />\n    <meta name="apple-mobile-web-app-title" content="Python.org" />\n    <meta name="apple-mobile-web-app-capable" content="yes" />\n    <meta name="apple-mobile-w
# ...

# %%
driver.close()
